# %% [markdown]
# # Assignment-3 Government data set (Industry Wise Sanctions for the Year 2023-2024)
# # 2211CS010612
# # Y.Dharanidhar
# # Group-3[72]

# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\siddu\Downloads\IND2324rename.csv")
df
# Out:
#     Sl No                            Industry  Rs in crore  Unnamed: 3  \
# 0     1.0            Hotel / Restaurant etc.        151.81         NaN
# 1     2.0                       Health Sector        84.83         NaN
# 2     3.0         Construction activity (CRE)        36.61         NaN
# 3     4.0                    Food & Beverages        81.87         NaN
# 4     5.0                        Engineering        128.69         NaN
# 5     6.0              Non-metallic Products         65.53         NaN
# 6     7.0         Miscellaneous Manufacturing       115.02         NaN
# 7     8.0                           Chemicals        25.19         NaN
# 8     9.0                              Others        16.73         NaN
# 9    10.0       Textiles & Readymade Garments        39.38         NaN
# 10   11.0            Rubber & Rubber Products         0.75         NaN
# 11   12.0               Printing & Publishing        10.26         NaN
# 12   13.0                         Basic Metal        23.81         NaN
# 13   14.0     Transport / Transport equipment        10.34         NaN
# 14   15.0  Wood & Cork / Furniture & Fixtures        17.95         NaN
# 15   16.0              Paper & Paper products        18.36         NaN
# 16    NaN                                 NaN          NaN         NaN
# 17    NaN                                 NaN          NaN         NaN
# 18    NaN                                 NaN          NaN         NaN
# 19    NaN                                 NaN          NaN         NaN
# 20    NaN                                 NaN          NaN         NaN
# 21    NaN                                 NaN          NaN         NaN
# 22    NaN                                 NaN          NaN         NaN
# 23    NaN                                 NaN          NaN         NaN
# 24    NaN                                 NaN          NaN         NaN
# 25    NaN                                 NaN          NaN         NaN
# 26    NaN                                 NaN          NaN         NaN
# 27    NaN                                 NaN          NaN         NaN
# 28    NaN                                 NaN          NaN         NaN
# 29    NaN                                 NaN          NaN         NaN
# 30    NaN                                 NaN          NaN         NaN
# 31    NaN                                 NaN          NaN         NaN
# 32    NaN                                 NaN          NaN         NaN
# 33    NaN                                 NaN          NaN         NaN
# 34    NaN                                 NaN          NaN         NaN
# 35    NaN                                 NaN          NaN         NaN
# 36    NaN                                 NaN          NaN         NaN
# 37    NaN                                 NaN          NaN         NaN
# 38    NaN                                 NaN          NaN         NaN
# 39    NaN                                 NaN          NaN         NaN
# 40    NaN                                 NaN          NaN         NaN
# 41    NaN                                 NaN          NaN         NaN
# 42    NaN                                 NaN          NaN         NaN
# 43    NaN                                 NaN          NaN         NaN
# 44    NaN                                 NaN          NaN         NaN
# 45    NaN                                 NaN          NaN         NaN
#
#     Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0          NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN
# 30         NaN         NaN         NaN         NaN
# 31         NaN         NaN         NaN         NaN
# 32         NaN         NaN         NaN         NaN
# 33         NaN         NaN         NaN         NaN
# 34         NaN         NaN         NaN         NaN
# 35         NaN         NaN         NaN         NaN
# 36         NaN         NaN         NaN         NaN
# 37         NaN         NaN         NaN         NaN
# 38         NaN         NaN         NaN         NaN
# 39         NaN         NaN         NaN         NaN
# 40         NaN         NaN         NaN         NaN
# 41         NaN         NaN         NaN         NaN
# 42         NaN         NaN         NaN         NaN
# 43         NaN         NaN         NaN         NaN
# 44         NaN         NaN         NaN         NaN
# 45         NaN         NaN         NaN         NaN

# %% [markdown]
# # Load the dataset from the given path for futhur analysics

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sl No        16 non-null     float64
#  1   Industry     16 non-null     object
#  2   Rs in crore  16 non-null     float64
#  3   Unnamed: 3   0 non-null      float64
#  4   Unnamed: 4   0 non-null      float64
#  5   Unnamed: 5   0 non-null      float64
#  6   Unnamed: 6   0 non-null      float64
#  7   Unnamed: 7   0 non-null      float64
# dtypes: float64(7), object(1)
# memory usage: 3.0+ KB

# %% [markdown]
# # Display basic information of the dataset

# %%
df.head(5)
# Out:
#    Sl No                     Industry  Rs in crore  Unnamed: 3  Unnamed: 4  \
# 0    1.0     Hotel / Restaurant etc.        151.81         NaN         NaN
# 1    2.0                Health Sector        84.83         NaN         NaN
# 2    3.0  Construction activity (CRE)        36.61         NaN         NaN
# 3    4.0             Food & Beverages        81.87         NaN         NaN
# 4    5.0                 Engineering        128.69         NaN         NaN
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %% [markdown]
# # Display the first five rows

# %%
df = df.drop(columns=['Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'])

# %% [markdown]
# # Cleaning  the dataset by removing empty columns

# %%
df = df.dropna(subset=['Industry'])

# %% [markdown]
# # Clean the dataset by removing empty rows.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 0 to 15
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sl No        16 non-null     float64
#  1   Industry     16 non-null     object
#  2   Rs in crore  16 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 512.0+ bytes

# %% [markdown]
# # Displaying  basic information of the dataset after Cleaning

# %%
df.head()
# Out:
#    Sl No                     Industry  Rs in crore
# 0    1.0     Hotel / Restaurant etc.        151.81
# 1    2.0                Health Sector        84.83
# 2    3.0  Construction activity (CRE)        36.61
# 3    4.0             Food & Beverages        81.87
# 4    5.0                 Engineering        128.69

# %% [markdown]
# # Displaying the first five rows after cleaning

# %%
df.tail()
# Out:
#     Sl_No                            Industry  Rs in crore
# 11     12               Printing & Publishing        10.26
# 12     13                         Basic Metal        23.81
# 13     14     Transport / Transport equipment        10.34
# 14     15  Wood & Cork / Furniture & Fixtures        17.95
# 15     16              Paper & Paper products        18.36

# %% [markdown]
# # Displaying the last five rows after cleaning

# %%
df.columns
# Out:
# Index(['Sl No', 'Industry', 'Rs in crore'], dtype='object')

# %% [markdown]
# # Displaying  column names to check for hidden characters

# %%
df = df.rename(columns={"Sl No": "Sl_No"})

# %% [markdown]
# # Renaming the column SI No into SI_No

# %%
df["Sl_No"] = df["Sl_No"].astype(int)

# %% [markdown]
# # Converting 'Sl No' to integer data type

# %%
df.dtypes
# Out:
# Sl_No            int32
# Industry        object
# Rs in crore    float64
# dtype: object

# %% [markdown]
# # Verify the change

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Importing matplotlib and seaborn for data visualization

# %%
# Histogram of revenue distribution
plt.figure(figsize=(8, 6))
sns.histplot(df["Rs in crore"], bins=5, kde=True, color='blue')
plt.title("Revenue Distribution of Industries")
plt.xlabel("Revenue (Rs in crore)")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # This histogram shows how the revenues are distributed across industries ,  it suggests that most industries have lower revenues, with a few industries having very high revenues.

# %%
plt.figure(figsize=(8, 6))
sns.histplot(df[df["Rs in crore"] < 50]["Rs in crore"], bins=5, kde=True, color='purple', label="Small Industries", alpha=0.6)
sns.histplot(df[df["Rs in crore"] >= 50]["Rs in crore"], bins=5, kde=True, color='orange', label="Large Industries", alpha=0.6)
plt.legend()
plt.title("Comparison of Small vs. Large Industry Revenues")
plt.xlabel("Revenue (Rs in crore)")
plt.ylabel("Frequency")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # This histogram compares the revenue distribution of small industries (below ₹50 crore) and large industries (₹50 crore and above). The purple bars represent small industries, while the orange bars represent large industries. If one group has a higher frequency, it indicates that more industries fall within that revenue range.

# %%
# Bar chart of revenue per industry
plt.figure(figsize=(10, 6))
sns.barplot(y="Rs in crore", x="Industry", data=df, palette="viridis" )
plt.xticks(rotation=45, ha='right')
plt.title("Industry Revenue Comparison")
plt.xlabel("Industry")
plt.ylabel("Revenue (Rs in crore)")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()
# Out:
# C:\Users\siddu\AppData\Local\Temp\ipykernel_21116\3322392352.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(y="Rs in crore", x="Industry", data=df, palette="viridis" )

# %%
# Bar chart of revenue per industry
plt.figure(figsize=(10, 6))
sns.barplot(y="Industry", x="Rs in crore", data=df)#, palette="viridis"
plt.title("Industry Revenue Comparison")
plt.xlabel("Revenue (Rs in crore)")
plt.ylabel("Industry")
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # This bar chart compares the revenues of different industries,Industries with the highest revenue can be quickly identified as the longest bars,Smaller bars indicate industries with lower revenue

# %%
# Pie chart of revenue distribution by industry
plt.figure(figsize=(8, 8))
plt.pie(df["Rs in crore"], labels=df["Industry"], autopct='%1.1f%%', colors=sns.color_palette("pastel"))
plt.title("Revenue Share by Industry")
plt.show()

# %% [markdown]
# # This pie chart shows the proportion of total revenue contributed by each industry ,few industries occupy most of the pie, it indicates that a few industries dominate revenue generation.

# %%
df_grouped = df.groupby("Industry")["Rs in crore"].sum()
top_10 = df_grouped.nlargest(10)
others = df_grouped.sum() - top_10.sum()


top_10["Others"] = others

plt.figure(figsize=(8, 8))
top_10.plot.pie(autopct='%1.1f%%', startangle=140, cmap="Set3")
plt.title("Top 10 Industries by Revenue (With Others)")
plt.ylabel("")
plt.show()

# %% [markdown]
# # This pie chart represents the share of total revenue contributed by the top 10 industries, with the remaining industries grouped as "Others." The larger sections indicate that a few industries generate the majority of the revenue, while smaller industries contribute comparatively less.

# %%
plt.figure(figsize=(8, 8))
df_count = df["Industry"].value_counts()
df_count.plot.pie(autopct='%1.1f%%', startangle=140, cmap="coolwarm")
plt.title("Number of Companies per Industry")
plt.ylabel("")
plt.show()

# %% [markdown]
# # This pie chart visually shows how many companies belong to each industry. Each slice represents an industry, and its size is proportional to the number of companies in that industry.

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x="Industry", y="Rs in crore", data=df, color="lightblue", width=0.6)
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability
plt.title("Boxplot of Industry Revenues by Industry")
plt.xlabel("Industry")
plt.ylabel("Revenue (Rs in crore)")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # This boxplot shows the revenue distribution across different industries. Some industries have a wider spread, indicating high variability in revenue, while others have a more concentrated range. A few industries may have higher median revenues, suggesting they dominate in revenue generation.

# %%
from scipy import stats

# %%
desc_stats = df["Rs in crore"].describe()
desc_stats
# Out:
# count     16.000000
# mean      51.695625
# std       47.269057
# min        0.750000
# 25%       17.645000
# 50%       30.900000
# 75%       82.610000
# max      151.810000
# Name: Rs in crore, dtype: float64

# %% [markdown]
# # This summary provides key statistics about industry revenue. It includes the average revenue (mean), median (50% value), minimum and maximum revenues, and standard deviation, which shows how much revenues vary across industries. A high standard deviation indicates large differences between industries, while a small range suggests similar revenues.

# %%
t_stat, p_value = stats.ttest_1samp(df["Rs in crore"], 100)
(t_stat, p_value)
# Out:
# (-4.087610623823906, 0.0009703322797434481)

# %% [markdown]
# # This t-test checks whether the average industry revenue is significantly different from ₹100 crore. A high p-value (greater than 0.05) suggests no significant difference, while a low p-value (less than 0.05) indicates that the industry revenue is significantly different from ₹100 crore. The t-statistic shows how far the sample mean deviates from the hypothesized value.

# %% [markdown]
# # THANK YOU
